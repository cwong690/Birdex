# %%
import json # to work with json file format
from bs4 import BeautifulSoup # to parse html
import pandas as pd

# %%
wildlife = []
with open('wcs_camera_traps.json') as f:
    wildlife.append(json.load(f))
#         try:
#             reports.append(json.loads(k))
#         except:
#             continue

# %%
wildlife[0]
# Out:
# {'info': {'version': '1.0',
#   'description': 'Camera trap data from the Wildlife Conservation Society',
#   'date_created': '2019',
#   'contributor': 'WCS'},
#  'images': [{'id': 'c6fe0cba-92d4-11e9-ac1e-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000010',
#    'file_name': 'animals/0000/0000.jpg',
#    'frame_num': 6,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6fea8fa-92d4-11e9-a58a-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000011',
#    'file_name': 'animals/0000/0001.jpg',
#    'frame_num': 7,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6fea8fc-92d4-11e9-8c7a-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000012',
#    'file_name': 'animals/0000/0002.jpg',
#    'frame_num': 8,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6fed00c-92d4-11e9-97a0-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000013',
#    'file_name': 'animals/0000/0003.jpg',
#    'frame_num': 9,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6fed00e-92d4-11e9-97d9-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000014',
#    'file_name': 'animals/0000/0004.jpg',
#    'frame_num': 10,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6fed010-92d4-11e9-b4b0-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000015',
#    'file_name': 'animals/0000/0005.jpg',
#    'frame_num': 11,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6fef724-92d4-11e9-8fa8-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000016',
#    'file_name': 'animals/0000/0006.jpg',
#    'frame_num': 12,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6fef726-92d4-11e9-927f-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000017',
#    'file_name': 'animals/0000/0007.jpg',
#    'frame_num': 13,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6fef728-92d4-11e9-bfe2-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000018',
#    'file_name': 'animals/0000/0008.jpg',
#    'frame_num': 14,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6ff1e46-92d4-11e9-913d-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000019',
#    'file_name': 'animals/0000/0009.jpg',
#    'frame_num': 15,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6ff1e48-92d4-11e9-b4a8-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000020',
#    'file_name': 'animals/0000/0010.jpg',
#    'frame_num': 16,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6ff1e4a-92d4-11e9-be2b-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000021',
#    'file_name': 'animals/0000/0011.jpg',
#    'frame_num': 17,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6ff1e4c-92d4-11e9-a390-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000022',
#    'file_name': 'animals/0000/0012.jpg',
#    'frame_num': 18,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6ff4541-92d4-11e9-93c4-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000023',
#    'file_name': 'animals/0000/0013.jpg',
#    'frame_num': 19,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6ff4543-92d4-11e9-982b-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000024',
#    'file_name': 'animals/0000/0014.jpg',
#    'frame_num': 20,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6ff4545-92d4-11e9-8a62-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000025',
#    'file_name': 'animals/0000/0015.jpg',
#    'frame_num': 21,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6ff6c52-92d4-11e9-a29e-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000026',
#    'file_name': 'animals/0000/0016.jpg',
#    'frame_num': 22,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6ff6c54-92d4-11e9-9879-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000027',
#    'file_name': 'animals/0000/0017.jpg',
#    'frame_num': 23,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6ff6c56-92d4-11e9-b211-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000028',
#    'file_name': 'animals/0000/0018.jpg',
#    'frame_num': 24,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6ff6c58-92d4-11e9-b1c4-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000029',
#    'file_name': 'animals/0000/0019.jpg',
#    'frame_num': 25,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6ff9363-92d4-11e9-9029-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000030',
#    'file_name': 'animals/0000/0020.jpg',
#    'frame_num': 26,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6ff9365-92d4-11e9-a78b-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000031',
#    'file_name': 'animals/0000/0021.jpg',
#    'frame_num': 27,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6ff9367-92d4-11e9-8a75-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000032',
#    'file_name': 'animals/0000/0022.jpg',
#    'frame_num': 28,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6ffba76-92d4-11e9-9a13-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000033',
#    'file_name': 'animals/0000/0023.jpg',
#    'frame_num': 29,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6ffba78-92d4-11e9-968e-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000034',
#    'file_name': 'animals/0000/0024.jpg',
#    'frame_num': 30,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6ffba7a-92d4-11e9-9b1b-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000035',
#    'file_name': 'animals/0000/0025.jpg',
#    'frame_num': 31,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6ffe180-92d4-11e9-9bd0-000d3a74c7de',
#    'wcs_id': 'bol-001-d0005-i000036',
#    'file_name': 'animals/0000/0026.jpg',
#    'frame_num': 32,
#    'seq_id': 'bol-001-d0005-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '0',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 32,
#    'status': ''},
#   {'id': 'c6ffe182-92d4-11e9-8eb8-000d3a74c7de',
#    'wcs_id': 'bol-001-d0001-i000037',
#    'file_name': 'animals/0000/0027.jpg',
#    'frame_num': 1,
#    'seq_id': 'bol-001-d0001-1',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-25 00:00:00.000',
#    'location': '1',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 1,
#    'status': ''},
#   {'id': 'c6ffe184-92d4-11e9-8d62-000d3a74c7de',
#    'wcs_id': 'bol-001-d0001-i000038',
#    'file_name': 'animals/0000/0028.jpg',
#    'frame_num': 1,
#    'seq_id': 'bol-001-d0001-2',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-26 00:00:00.000',
#    'location': '1',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 1,
#    'status': ''},
#   {'id': 'c6ffe186-92d4-11e9-ba92-000d3a74c7de',
#    'wcs_id': 'bol-001-d0001-i000041',
#    'file_name': 'animals/0000/0029.jpg',
#    'frame_num': 2,
#    'seq_id': 'bol-001-d0001-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-27 00:00:00.000',
#    'location': '1',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 2,
#    'status': ''},
#   {'id': 'c7000891-92d4-11e9-9506-000d3a74c7de',
#    'wcs_id': 'bol-001-d0001-i000047',
#    'file_name': 'animals/0000/0030.jpg',
#    'frame_num': 1,
#    'seq_id': 'bol-001-d0001-4',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '1',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 1,
#    'status': ''},
#   {'id': 'c7000893-92d4-11e9-8f3d-000d3a74c7de',
#    'wcs_id': 'bol-001-d0001-i000048',
#    'file_name': 'animals/0000/0031.jpg',
#    'frame_num': 1,
#    'seq_id': 'bol-001-d0001-5',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-01 00:00:00.000',
#    'location': '1',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 11,
#    'status': ''},
#   {'id': 'c7000895-92d4-11e9-b18c-000d3a74c7de',
#    'wcs_id': 'bol-001-d0001-i000049',
#    'file_name': 'animals/0000/0032.jpg',
#    'frame_num': 2,
#    'seq_id': 'bol-001-d0001-5',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-01 00:00:00.000',
#    'location': '1',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 11,
#    'status': ''},
#   {'id': 'c7002f9c-92d4-11e9-a657-000d3a74c7de',
#    'wcs_id': 'bol-001-d0001-i000050',
#    'file_name': 'animals/0000/0033.jpg',
#    'frame_num': 3,
#    'seq_id': 'bol-001-d0001-5',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-01 00:00:00.000',
#    'location': '1',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 11,
#    'status': ''},
#   {'id': 'c7002f9e-92d4-11e9-9f56-000d3a74c7de',
#    'wcs_id': 'bol-001-d0001-i000051',
#    'file_name': 'animals/0000/0034.jpg',
#    'frame_num': 4,
#    'seq_id': 'bol-001-d0001-5',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-01 00:00:00.000',
#    'location': '1',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 11,
#    'status': ''},
#   {'id': 'c7002fa0-92d4-11e9-b00a-000d3a74c7de',
#    'wcs_id': 'bol-001-d0001-i000052',
#    'file_name': 'animals/0000/0035.jpg',
#    'frame_num': 5,
#    'seq_id': 'bol-001-d0001-5',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-01 00:00:00.000',
#    'location': '1',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 11,
#    'status': ''},
#   {'id': 'c70056b0-92d4-11e9-affb-000d3a74c7de',
#    'wcs_id': 'bol-001-d0001-i000053',
#    'file_name': 'animals/0000/0036.jpg',
#    'frame_num': 6,
#    'seq_id': 'bol-001-d0001-5',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-01 00:00:00.000',
#    'location': '1',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 11,
#    'status': ''},
#   {'id': 'c70056b2-92d4-11e9-94f3-000d3a74c7de',
#    'wcs_id': 'bol-001-d0001-i000054',
#    'file_name': 'animals/0000/0037.jpg',
#    'frame_num': 7,
#    'seq_id': 'bol-001-d0001-5',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-01 00:00:00.000',
#    'location': '1',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 11,
#    'status': ''},
#   {'id': 'c70056b4-92d4-11e9-bbfd-000d3a74c7de',
#    'wcs_id': 'bol-001-d0001-i000055',
#    'file_name': 'animals/0000/0038.jpg',
#    'frame_num': 8,
#    'seq_id': 'bol-001-d0001-5',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-01 00:00:00.000',
#    'location': '1',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 11,
#    'status': ''},
#   {'id': 'c70056b6-92d4-11e9-a19b-000d3a74c7de',
#    'wcs_id': 'bol-001-d0001-i000056',
#    'file_name': 'animals/0000/0039.jpg',
#    'frame_num': 9,
#    'seq_id': 'bol-001-d0001-5',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-01 00:00:00.000',
#    'location': '1',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 11,
#    'status': ''},
#   {'id': 'c7007dc3-92d4-11e9-8828-000d3a74c7de',
#    'wcs_id': 'bol-001-d0001-i000057',
#    'file_name': 'animals/0000/0040.jpg',
#    'frame_num': 10,
#    'seq_id': 'bol-001-d0001-5',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-01 00:00:00.000',
#    'location': '1',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 11,
#    'status': ''},
#   {'id': 'c7007dc5-92d4-11e9-9625-000d3a74c7de',
#    'wcs_id': 'bol-001-d0001-i000058',
#    'file_name': 'animals/0000/0041.jpg',
#    'frame_num': 11,
#    'seq_id': 'bol-001-d0001-5',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-01 00:00:00.000',
#    'location': '1',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 11,
#    'status': ''},
#   {'id': 'c7007dc7-92d4-11e9-895c-000d3a74c7de',
#    'wcs_id': 'bol-001-d0001-i000059',
#    'file_name': 'animals/0000/0042.jpg',
#    'frame_num': 1,
#    'seq_id': 'bol-001-d0001-6',
#    'country_code': 'bol',
#    'match_level': 1,
#    'datetime': '2001-03-02 00:00:00.000',
#    'location': '1',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 3,
#    'status': ''},
#   {'id': 'c700a4ca-92d4-11e9-80fc-000d3a74c7de',
#    'wcs_id': 'bol-001-d0001-i000060',
#    'file_name': 'animals/0000/0043.jpg',
#    'frame_num': 2,
#    'seq_id': 'bol-001-d0001-6',
#    'country_code': 'bol',
#    'match_level': 1,
#    'datetime': '2001-03-02 00:00:00.000',
#    'location': '1',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 3,
#    'status': ''},
#   {'id': 'c700a4cc-92d4-11e9-8331-000d3a74c7de',
#    'wcs_id': 'bol-001-d0001-i000061',
#    'file_name': 'animals/0000/0044.jpg',
#    'frame_num': 3,
#    'seq_id': 'bol-001-d0001-6',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-02 00:00:00.000',
#    'location': '1',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 3,
#    'status': ''},
#   {'id': 'c700a4ce-92d4-11e9-a75a-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000069',
#    'file_name': 'animals/0000/0045.jpg',
#    'frame_num': 3,
#    'seq_id': 'bol-001-d0028-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-05 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 21,
#    'status': ''},
#   {'id': 'c700cbda-92d4-11e9-aa1d-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000070',
#    'file_name': 'animals/0000/0046.jpg',
#    'frame_num': 4,
#    'seq_id': 'bol-001-d0028-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-05 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 21,
#    'status': ''},
#   {'id': 'c700cbdc-92d4-11e9-b7f4-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000071',
#    'file_name': 'animals/0000/0047.jpg',
#    'frame_num': 5,
#    'seq_id': 'bol-001-d0028-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-05 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 21,
#    'status': ''},
#   {'id': 'c700cbde-92d4-11e9-9cb1-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000072',
#    'file_name': 'animals/0000/0048.jpg',
#    'frame_num': 6,
#    'seq_id': 'bol-001-d0028-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-05 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 21,
#    'status': ''},
#   {'id': 'c700cbe0-92d4-11e9-bef5-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000073',
#    'file_name': 'animals/0000/0049.jpg',
#    'frame_num': 7,
#    'seq_id': 'bol-001-d0028-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-05 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 21,
#    'status': ''},
#   {'id': 'c700f2ee-92d4-11e9-87a4-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000074',
#    'file_name': 'animals/0000/0050.jpg',
#    'frame_num': 8,
#    'seq_id': 'bol-001-d0028-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-05 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 21,
#    'status': ''},
#   {'id': 'c700f2f0-92d4-11e9-8348-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000075',
#    'file_name': 'animals/0000/0051.jpg',
#    'frame_num': 9,
#    'seq_id': 'bol-001-d0028-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-05 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 21,
#    'status': ''},
#   {'id': 'c700f2f2-92d4-11e9-a4dc-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000076',
#    'file_name': 'animals/0000/0052.jpg',
#    'frame_num': 10,
#    'seq_id': 'bol-001-d0028-3',
#    'country_code': 'bol',
#    'match_level': 1,
#    'datetime': '2001-03-05 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 21,
#    'status': ''},
#   {'id': 'c7011a00-92d4-11e9-bc16-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000077',
#    'file_name': 'animals/0000/0053.jpg',
#    'frame_num': 11,
#    'seq_id': 'bol-001-d0028-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-05 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 21,
#    'status': ''},
#   {'id': 'c7011a02-92d4-11e9-a81f-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000078',
#    'file_name': 'animals/0000/0054.jpg',
#    'frame_num': 12,
#    'seq_id': 'bol-001-d0028-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-05 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 21,
#    'status': ''},
#   {'id': 'c7011a04-92d4-11e9-91db-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000079',
#    'file_name': 'animals/0000/0055.jpg',
#    'frame_num': 13,
#    'seq_id': 'bol-001-d0028-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-05 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 21,
#    'status': ''},
#   {'id': 'c7011a06-92d4-11e9-af02-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000080',
#    'file_name': 'animals/0000/0056.jpg',
#    'frame_num': 14,
#    'seq_id': 'bol-001-d0028-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-05 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 21,
#    'status': ''},
#   {'id': 'c701410b-92d4-11e9-ae73-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000081',
#    'file_name': 'animals/0000/0057.jpg',
#    'frame_num': 15,
#    'seq_id': 'bol-001-d0028-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-05 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 21,
#    'status': ''},
#   {'id': 'c701410d-92d4-11e9-a6bb-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000082',
#    'file_name': 'animals/0000/0058.jpg',
#    'frame_num': 16,
#    'seq_id': 'bol-001-d0028-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-05 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 21,
#    'status': ''},
#   {'id': 'c701410f-92d4-11e9-9fc0-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000083',
#    'file_name': 'animals/0000/0059.jpg',
#    'frame_num': 17,
#    'seq_id': 'bol-001-d0028-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-05 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 21,
#    'status': ''},
#   {'id': 'c701681c-92d4-11e9-b8cb-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000084',
#    'file_name': 'animals/0000/0060.jpg',
#    'frame_num': 18,
#    'seq_id': 'bol-001-d0028-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-05 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 21,
#    'status': ''},
#   {'id': 'c701681e-92d4-11e9-bcae-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000085',
#    'file_name': 'animals/0000/0061.jpg',
#    'frame_num': 19,
#    'seq_id': 'bol-001-d0028-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-05 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 21,
#    'status': ''},
#   {'id': 'c7016820-92d4-11e9-8c4e-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000086',
#    'file_name': 'animals/0000/0062.jpg',
#    'frame_num': 20,
#    'seq_id': 'bol-001-d0028-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-05 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 21,
#    'status': ''},
#   {'id': 'c7018f34-92d4-11e9-af3d-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000087',
#    'file_name': 'animals/0000/0063.jpg',
#    'frame_num': 21,
#    'seq_id': 'bol-001-d0028-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-05 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 21,
#    'status': ''},
#   {'id': 'c7018f36-92d4-11e9-a95d-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000088',
#    'file_name': 'animals/0000/0064.jpg',
#    'frame_num': 1,
#    'seq_id': 'bol-001-d0028-4',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-06 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 8,
#    'status': ''},
#   {'id': 'c7018f38-92d4-11e9-b667-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000089',
#    'file_name': 'animals/0000/0065.jpg',
#    'frame_num': 2,
#    'seq_id': 'bol-001-d0028-4',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-06 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 8,
#    'status': ''},
#   {'id': 'c7018f3a-92d4-11e9-8828-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000090',
#    'file_name': 'animals/0000/0066.jpg',
#    'frame_num': 3,
#    'seq_id': 'bol-001-d0028-4',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-06 00:00:00.000',
#    'location': '2',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 8,
#    'status': ''},
#   {'id': 'c701b647-92d4-11e9-becf-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000091',
#    'file_name': 'animals/0000/0067.jpg',
#    'frame_num': 4,
#    'seq_id': 'bol-001-d0028-4',
#    'country_code': 'bol',
#    'match_level': 1,
#    'datetime': '2001-03-06 00:00:00.000',
#    'location': '2',
#    'width': 595,
#    'height': 394,
#    'corrupt': False,
#    'seq_num_frames': 8,
#    'status': ''},
#   {'id': 'c701b649-92d4-11e9-8e67-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000092',
#    'file_name': 'animals/0000/0068.jpg',
#    'frame_num': 5,
#    'seq_id': 'bol-001-d0028-4',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-06 00:00:00.000',
#    'location': '2',
#    'width': 595,
#    'height': 394,
#    'corrupt': False,
#    'seq_num_frames': 8,
#    'status': ''},
#   {'id': 'c701b64b-92d4-11e9-9957-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000093',
#    'file_name': 'animals/0000/0069.jpg',
#    'frame_num': 6,
#    'seq_id': 'bol-001-d0028-4',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-06 00:00:00.000',
#    'location': '2',
#    'width': 595,
#    'height': 394,
#    'corrupt': False,
#    'seq_num_frames': 8,
#    'status': ''},
#   {'id': 'c701dd54-92d4-11e9-908e-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000094',
#    'file_name': 'animals/0000/0070.jpg',
#    'frame_num': 7,
#    'seq_id': 'bol-001-d0028-4',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-06 00:00:00.000',
#    'location': '2',
#    'width': 595,
#    'height': 394,
#    'corrupt': False,
#    'seq_num_frames': 8,
#    'status': ''},
#   {'id': 'c701dd56-92d4-11e9-99cf-000d3a74c7de',
#    'wcs_id': 'bol-001-d0028-i000095',
#    'file_name': 'animals/0000/0071.jpg',
#    'frame_num': 8,
#    'seq_id': 'bol-001-d0028-4',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-06 00:00:00.000',
#    'location': '2',
#    'width': 595,
#    'height': 394,
#    'corrupt': False,
#    'seq_num_frames': 8,
#    'status': ''},
#   {'id': 'c701dd58-92d4-11e9-ba44-000d3a74c7de',
#    'wcs_id': 'bol-001-d0027-i000101',
#    'file_name': 'animals/0000/0072.jpg',
#    'frame_num': 4,
#    'seq_id': 'bol-001-d0027-2',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '3',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 8,
#    'status': ''},
#   {'id': 'c702045e-92d4-11e9-8d16-000d3a74c7de',
#    'wcs_id': 'bol-001-d0027-i000102',
#    'file_name': 'animals/0000/0073.jpg',
#    'frame_num': 5,
#    'seq_id': 'bol-001-d0027-2',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '3',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 8,
#    'status': ''},
#   {'id': 'c7020460-92d4-11e9-8c10-000d3a74c7de',
#    'wcs_id': 'bol-001-d0027-i000103',
#    'file_name': 'animals/0000/0074.jpg',
#    'frame_num': 6,
#    'seq_id': 'bol-001-d0027-2',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '3',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 8,
#    'status': ''},
#   {'id': 'c7020462-92d4-11e9-99ab-000d3a74c7de',
#    'wcs_id': 'bol-001-d0027-i000104',
#    'file_name': 'animals/0000/0075.jpg',
#    'frame_num': 7,
#    'seq_id': 'bol-001-d0027-2',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '3',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 8,
#    'status': ''},
#   {'id': 'c7020464-92d4-11e9-9be9-000d3a74c7de',
#    'wcs_id': 'bol-001-d0027-i000105',
#    'file_name': 'animals/0000/0076.jpg',
#    'frame_num': 8,
#    'seq_id': 'bol-001-d0027-2',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-02-28 00:00:00.000',
#    'location': '3',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 8,
#    'status': ''},
#   {'id': 'c7022be4-92d4-11e9-b19c-000d3a74c7de',
#    'wcs_id': 'bol-001-d0027-i000110',
#    'file_name': 'animals/0000/0077.jpg',
#    'frame_num': 1,
#    'seq_id': 'bol-001-d0027-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-03 00:00:00.000',
#    'location': '3',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 2,
#    'status': ''},
#   {'id': 'c7022be6-92d4-11e9-bf1e-000d3a74c7de',
#    'wcs_id': 'bol-001-d0027-i000111',
#    'file_name': 'animals/0000/0078.jpg',
#    'frame_num': 2,
#    'seq_id': 'bol-001-d0027-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-03 00:00:00.000',
#    'location': '3',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 2,
#    'status': ''},
#   {'id': 'c7022be8-92d4-11e9-8e5c-000d3a74c7de',
#    'wcs_id': 'bol-001-d0027-i000112',
#    'file_name': 'animals/0000/0079.jpg',
#    'frame_num': 1,
#    'seq_id': 'bol-001-d0027-4',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-04 00:00:00.000',
#    'location': '3',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 1,
#    'status': ''},
#   {'id': 'c702527e-92d4-11e9-a756-000d3a74c7de',
#    'wcs_id': 'bol-001-d0027-i000113',
#    'file_name': 'animals/0000/0080.jpg',
#    'frame_num': 1,
#    'seq_id': 'bol-001-d0027-5',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-05 00:00:00.000',
#    'location': '3',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 2,
#    'status': ''},
#   {'id': 'c7025280-92d4-11e9-898b-000d3a74c7de',
#    'wcs_id': 'bol-001-d0027-i000114',
#    'file_name': 'animals/0000/0081.jpg',
#    'frame_num': 2,
#    'seq_id': 'bol-001-d0027-5',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-05 00:00:00.000',
#    'location': '3',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 2,
#    'status': ''},
#   {'id': 'c7025282-92d4-11e9-b571-000d3a74c7de',
#    'wcs_id': 'bol-001-d0027-i000115',
#    'file_name': 'animals/0000/0082.jpg',
#    'frame_num': 1,
#    'seq_id': 'bol-001-d0027-6',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-06 00:00:00.000',
#    'location': '3',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 1,
#    'status': ''},
#   {'id': 'c7025284-92d4-11e9-930f-000d3a74c7de',
#    'wcs_id': 'bol-001-d0027-i000116',
#    'file_name': 'animals/0000/0083.jpg',
#    'frame_num': 1,
#    'seq_id': 'bol-001-d0027-7',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '3',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 3,
#    'status': ''},
#   {'id': 'c7027991-92d4-11e9-9628-000d3a74c7de',
#    'wcs_id': 'bol-001-d0027-i000117',
#    'file_name': 'animals/0000/0084.jpg',
#    'frame_num': 2,
#    'seq_id': 'bol-001-d0027-7',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '3',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 3,
#    'status': ''},
#   {'id': 'c7027993-92d4-11e9-ac9c-000d3a74c7de',
#    'wcs_id': 'bol-001-d0027-i000118',
#    'file_name': 'animals/0000/0085.jpg',
#    'frame_num': 3,
#    'seq_id': 'bol-001-d0027-7',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '3',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 3,
#    'status': ''},
#   {'id': 'c7027995-92d4-11e9-a547-000d3a74c7de',
#    'wcs_id': 'bol-001-d0027-i000119',
#    'file_name': 'animals/0000/0086.jpg',
#    'frame_num': 1,
#    'seq_id': 'bol-001-d0027-8',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-10 00:00:00.000',
#    'location': '3',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 3,
#    'status': ''},
#   {'id': 'c702a09c-92d4-11e9-9d4e-000d3a74c7de',
#    'wcs_id': 'bol-001-d0027-i000120',
#    'file_name': 'animals/0000/0087.jpg',
#    'frame_num': 2,
#    'seq_id': 'bol-001-d0027-8',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-10 00:00:00.000',
#    'location': '3',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 3,
#    'status': ''},
#   {'id': 'c702a09e-92d4-11e9-8c04-000d3a74c7de',
#    'wcs_id': 'bol-001-d0027-i000121',
#    'file_name': 'animals/0000/0088.jpg',
#    'frame_num': 3,
#    'seq_id': 'bol-001-d0027-8',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-10 00:00:00.000',
#    'location': '3',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 3,
#    'status': ''},
#   {'id': 'c702a0a0-92d4-11e9-89e6-000d3a74c7de',
#    'wcs_id': 'bol-001-d0027-i000122',
#    'file_name': 'animals/0000/0089.jpg',
#    'frame_num': 1,
#    'seq_id': 'bol-001-d0027-9',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-12 00:00:00.000',
#    'location': '3',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 1,
#    'status': ''},
#   {'id': 'c702c7b0-92d4-11e9-94e6-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000131',
#    'file_name': 'animals/0000/0090.jpg',
#    'frame_num': 1,
#    'seq_id': 'bol-001-d0015-2',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-07 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 1,
#    'status': ''},
#   {'id': 'c702c7b2-92d4-11e9-b0ef-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000132',
#    'file_name': 'animals/0000/0091.jpg',
#    'frame_num': 1,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c702c7b4-92d4-11e9-9597-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000133',
#    'file_name': 'animals/0000/0092.jpg',
#    'frame_num': 2,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c702c7b6-92d4-11e9-9942-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000134',
#    'file_name': 'animals/0000/0093.jpg',
#    'frame_num': 3,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c702eec0-92d4-11e9-aa3f-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000135',
#    'file_name': 'animals/0000/0094.jpg',
#    'frame_num': 4,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c702eec2-92d4-11e9-84b8-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000136',
#    'file_name': 'animals/0000/0095.jpg',
#    'frame_num': 5,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c702eec4-92d4-11e9-a8a0-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000137',
#    'file_name': 'animals/0000/0096.jpg',
#    'frame_num': 6,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c70315d0-92d4-11e9-89e0-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000138',
#    'file_name': 'animals/0000/0097.jpg',
#    'frame_num': 7,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c70315d2-92d4-11e9-a739-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000139',
#    'file_name': 'animals/0000/0098.jpg',
#    'frame_num': 8,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c70315d4-92d4-11e9-845d-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000140',
#    'file_name': 'animals/0000/0099.jpg',
#    'frame_num': 9,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c70315d6-92d4-11e9-bef0-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000141',
#    'file_name': 'animals/0000/0100.jpg',
#    'frame_num': 10,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c7033ce3-92d4-11e9-baed-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000142',
#    'file_name': 'animals/0000/0101.jpg',
#    'frame_num': 11,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c7033ce5-92d4-11e9-91d7-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000143',
#    'file_name': 'animals/0000/0102.jpg',
#    'frame_num': 12,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c7033ce7-92d4-11e9-89d6-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000144',
#    'file_name': 'animals/0000/0103.jpg',
#    'frame_num': 13,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c70363ee-92d4-11e9-8e6d-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000145',
#    'file_name': 'animals/0000/0104.jpg',
#    'frame_num': 14,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c70363f0-92d4-11e9-b84b-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000146',
#    'file_name': 'animals/0000/0105.jpg',
#    'frame_num': 15,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c70363f2-92d4-11e9-8860-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000147',
#    'file_name': 'animals/0000/0106.jpg',
#    'frame_num': 16,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c7038afe-92d4-11e9-b489-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000148',
#    'file_name': 'animals/0000/0107.jpg',
#    'frame_num': 17,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c7038b00-92d4-11e9-997a-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000149',
#    'file_name': 'animals/0000/0108.jpg',
#    'frame_num': 18,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c7038b02-92d4-11e9-992c-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000150',
#    'file_name': 'animals/0000/0109.jpg',
#    'frame_num': 19,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c703b210-92d4-11e9-b5a5-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000151',
#    'file_name': 'animals/0000/0110.jpg',
#    'frame_num': 20,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c703b212-92d4-11e9-8d26-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000152',
#    'file_name': 'animals/0000/0111.jpg',
#    'frame_num': 21,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c703b214-92d4-11e9-8f59-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000153',
#    'file_name': 'animals/0000/0112.jpg',
#    'frame_num': 22,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c703b216-92d4-11e9-bc8a-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000154',
#    'file_name': 'animals/0000/0113.jpg',
#    'frame_num': 23,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c703d91f-92d4-11e9-80af-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000155',
#    'file_name': 'animals/0000/0114.jpg',
#    'frame_num': 24,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c703d921-92d4-11e9-afdc-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000156',
#    'file_name': 'animals/0000/0115.jpg',
#    'frame_num': 25,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c703d923-92d4-11e9-8a40-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000157',
#    'file_name': 'animals/0000/0116.jpg',
#    'frame_num': 26,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c704002e-92d4-11e9-a2a8-000d3a74c7de',
#    'wcs_id': 'bol-001-d0015-i000158',
#    'file_name': 'animals/0000/0117.jpg',
#    'frame_num': 27,
#    'seq_id': 'bol-001-d0015-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 27,
#    'status': ''},
#   {'id': 'c7040030-92d4-11e9-8296-000d3a74c7de',
#    'wcs_id': 'bol-001-d0009-i000166',
#    'file_name': 'animals/0000/0118.jpg',
#    'frame_num': 5,
#    'seq_id': 'bol-001-d0009-1',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': nan,
#    'location': '5',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 6,
#    'status': ''},
#   {'id': 'c7040032-92d4-11e9-b1ae-000d3a74c7de',
#    'wcs_id': 'bol-001-d0009-i000167',
#    'file_name': 'animals/0000/0119.jpg',
#    'frame_num': 6,
#    'seq_id': 'bol-001-d0009-1',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': nan,
#    'location': '5',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 6,
#    'status': ''},
#   {'id': 'c7040034-92d4-11e9-9901-000d3a74c7de',
#    'wcs_id': 'bol-001-d0014-i000176',
#    'file_name': 'animals/0000/0120.jpg',
#    'frame_num': 2,
#    'seq_id': 'bol-001-d0014-2',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-07 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 2,
#    'status': ''},
#   {'id': 'c7042741-92d4-11e9-ba44-000d3a74c7de',
#    'wcs_id': 'bol-001-d0014-i000177',
#    'file_name': 'animals/0000/0121.jpg',
#    'frame_num': 1,
#    'seq_id': 'bol-001-d0014-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 26,
#    'status': ''},
#   {'id': 'c7042743-92d4-11e9-aa1e-000d3a74c7de',
#    'wcs_id': 'bol-001-d0014-i000178',
#    'file_name': 'animals/0000/0122.jpg',
#    'frame_num': 2,
#    'seq_id': 'bol-001-d0014-3',
#    'country_code': 'bol',
#    'match_level': 0,
#    'datetime': '2001-03-08 00:00:00.000',
#    'location': '4',
#    'width': 819,
#    'height': 542,
#    'corrupt': False,
#    'seq_num_frames': 26,
#    'status': ''},
#   {'id': 'c7042745-92d4-11e9-b8f0-000d3a74c7de',
#    'wcs_id': 'bol-001-d0014-i000179',
#    'file_name': 'animals/0000/0123.jpg',
#    'frame_num': 3,
#    'seq_id': 'bol-001-d0014-3',
#    'country_code': 'bol',
#    'match_level': 0,
# ...
#   {'id': 394, 'name': 'tupaia sp', 'count': 2},
#   {'id': 395, 'name': 'otus spilocephalus', 'count': 15},
#   {'id': 396, 'name': 'cyanoptila cyanomelana', 'count': 3},
#   {'id': 397, 'name': 'ficedula mugimaki', 'count': 1},
#   {'id': 398, 'name': 'dendrocitta occipitalas', 'count': 25},
#   {'id': 399, 'name': 'rattus tiomanicus sabae', 'count': 7},
#   {'id': 400, 'name': 'caloperdix oculea', 'count': 1},
#   {'id': 401, 'name': 'tragulus kanchil', 'count': 59},
#   {'id': 402, 'name': 'tragulus sp', 'count': 26},
#   {'id': 403, 'name': 'arctictis binturong', 'count': 33},
#   {'id': 404, 'name': 'misfire', 'count': 400},
#   {'id': 405, 'name': 'dendrocitta occipitalis', 'count': 6},
#   {'id': 406, 'name': 'niltava sumatrana', 'count': 2},
#   {'id': 407, 'name': 'mustela lutreolina', 'count': 2},
#   {'id': 408, 'name': 'leiothrix argentauris', 'count': 1},
#   {'id': 409, 'name': 'myiophoneus melanurus', 'count': 25},
#   {'id': 410, 'name': 'arborophila rubrirostris', 'count': 11},
#   {'id': 411, 'name': 'sundasciurus hippurus', 'count': 2},
#   {'id': 412, 'name': 'erithacus cyane', 'count': 2},
#   {'id': 413, 'name': 'lophura sp', 'count': 5},
#   {'id': 414, 'name': 'myiophoneus glaucinus', 'count': 31},
#   {'id': 415, 'name': 'lophura erythrophthalma', 'count': 3},
#   {'id': 416, 'name': 'spilornis cheela', 'count': 8},
#   {'id': 417, 'name': 'myiophoneus caeruleus', 'count': 1},
#   {'id': 418, 'name': 'herpestes semitorquatus', 'count': 3},
#   {'id': 419, 'name': 'collocalia linchi', 'count': 3},
#   {'id': 420, 'name': 'callosciurus notatus', 'count': 1},
#   {'id': 421, 'name': 'cavia aperea', 'count': 2},
#   {'id': 422, 'name': 'cerdocyon thous', 'count': 251},
#   {'id': 423, 'name': 'caracara plancus', 'count': 1},
#   {'id': 424, 'name': 'columbina talpacoti', 'count': 2},
#   {'id': 425, 'name': 'tolypeutes matacus', 'count': 1},
#   {'id': 426, 'name': 'tyto alba', 'count': 1},
#   {'id': 427, 'name': 'euphractus sexcinctus', 'count': 1},
#   {'id': 428, 'name': 'strigidae', 'count': 3},
#   {'id': 429, 'name': 'rhea americana', 'count': 2},
#   {'id': 430, 'name': 'cercocebus sanjei', 'count': 84},
#   {'id': 431, 'name': 'guttera pucherani', 'count': 61},
#   {'id': 432, 'name': 'cephalophus harveyi', 'count': 786},
#   {'id': 433, 'name': 'bdeogale crassicauda', 'count': 440},
#   {'id': 434, 'name': 'bdeogale jacksoni', 'count': 33},
#   {'id': 435, 'name': 'mungos mungo', 'count': 7},
#   {'id': 436, 'name': 'hystrix africaeaustralis', 'count': 46},
#   {'id': 437, 'name': 'papio cynocephalus', 'count': 21},
#   {'id': 438, 'name': 'cephalophus spadix', 'count': 25},
#   {'id': 439, 'name': 'paraxerus vexillarius', 'count': 141},
#   {'id': 440, 'name': 'paraxerus cepapi', 'count': 1},
#   {'id': 441, 'name': 'genetta maculata', 'count': 15},
#   {'id': 442, 'name': 'petrodromus tetradactylus', 'count': 118},
#   {'id': 443, 'name': 'rhynchocyon cirnei', 'count': 91},
#   {'id': 444, 'name': 'civettictis civetta', 'count': 15},
#   {'id': 445, 'name': 'dendrohyrax arboreus', 'count': 17},
#   {'id': 446, 'name': 'rhynchocyon udzungwensis', 'count': 134},
#   {'id': 447, 'name': 'philantomba monticola', 'count': 77},
#   {'id': 448, 'name': 'pogonocichla stellata', 'count': 1},
#   {'id': 449, 'name': 'xenoperdix udzungwensis', 'count': 11},
#   {'id': 450, 'name': 'sheppardia lowei', 'count': 1},
#   {'id': 451, 'name': 'columba larvata', 'count': 184},
#   {'id': 452, 'name': 'geokichla gurneyi', 'count': 35},
#   {'id': 453, 'name': 'procolobus gordonorum', 'count': 2},
#   {'id': 454, 'name': 'unknown rat', 'count': 1360},
#   {'id': 455, 'name': 'accipiter melanoleucus', 'count': 1},
#   {'id': 456, 'name': 'zoothera', 'count': 25},
#   {'id': 457, 'name': 'muscicapidae', 'count': 6},
#   {'id': 458, 'name': 'tauraco livingstonii', 'count': 1},
#   {'id': 459, 'name': 'xenoperdix obscurata', 'count': 4},
#   {'id': 460, 'name': 'stephanoaetus coronatus', 'count': 1},
#   {'id': 461, 'name': 'rhynchocyon petersi', 'count': 27},
#   {'id': 462, 'name': 'otolemur garnettii', 'count': 5},
#   {'id': 463, 'name': 'bycanistes brevis', 'count': 1},
#   {'id': 464, 'name': 'columba arquatrix', 'count': 1},
#   {'id': 465, 'name': 'paraxerus lucifer', 'count': 6},
#   {'id': 466, 'name': 'mazama chunyi', 'count': 760},
#   {'id': 467, 'name': 'cuniculus taczanowskii', 'count': 1504},
#   {'id': 468, 'name': 'didelphis pernigra', 'count': 10383},
#   {'id': 469, 'name': 'unknown coati', 'count': 1049},
#   {'id': 470, 'name': 'tremarctos ornatus', 'count': 462},
#   {'id': 471, 'name': 'chachalacha', 'count': 24},
#   {'id': 472, 'name': 'macaca arctoides', 'count': 1093},
#   {'id': 473, 'name': 'arctonyx collaris', 'count': 409},
#   {'id': 474, 'name': 'ursus thibetanus', 'count': 10},
#   {'id': 475, 'name': 'lophura nycthemera', 'count': 492},
#   {'id': 476, 'name': 'muntiacus rooseveltorum', 'count': 50},
#   {'id': 477, 'name': 'capricornis milneedwardsii', 'count': 148},
#   {'id': 478, 'name': 'zoothera dauma', 'count': 7},
#   {'id': 479, 'name': 'arborophila sp', 'count': 1},
#   {'id': 480, 'name': 'atherurus macrourus', 'count': 104},
#   {'id': 481, 'name': 'polyplectron bicalcaratum', 'count': 138},
#   {'id': 482, 'name': 'viverra zibetha', 'count': 213},
#   {'id': 483, 'name': 'chrotogale owstoni', 'count': 6},
#   {'id': 484, 'name': 'prionodon pardicolor', 'count': 18},
#   {'id': 485, 'name': 'dremomys rufigenis', 'count': 92},
#   {'id': 486, 'name': 'myophonus caerulus', 'count': 52},
#   {'id': 487, 'name': 'aonyx cinerea', 'count': 1},
#   {'id': 488, 'name': 'macaca assamensis', 'count': 21},
#   {'id': 489, 'name': 'arborophila brunneopectus', 'count': 4},
#   {'id': 490, 'name': 'herpestes urva', 'count': 230},
#   {'id': 491, 'name': 'viverricula indica', 'count': 88},
#   {'id': 492, 'name': 'bamusicola fytchii', 'count': 3},
#   {'id': 493, 'name': 'bos gaurus', 'count': 3},
#   {'id': 494, 'name': 'rhizomys sumatrensis', 'count': 1},
#   {'id': 495, 'name': 'areola grayii', 'count': 1},
#   {'id': 496, 'name': 'scolopax rusticola', 'count': 2},
#   {'id': 497, 'name': 'arborophila rufogularis', 'count': 17},
#   {'id': 498, 'name': 'hydrornis oatesi', 'count': 8},
#   {'id': 499, 'name': 'bubo sp', 'count': 1},
#   {'id': 500, 'name': 'hylopetes alboniger', 'count': 1},
#   {'id': 501, 'name': 'circus cyaneus', 'count': 1},
#   {'id': 502, 'name': 'myophonus caeruleus', 'count': 4},
#   {'id': 503, 'name': 'jynx torquilla', 'count': 8},
#   {'id': 504, 'name': 'felis chaus', 'count': 3},
#   {'id': 505, 'name': 'unknown civet', 'count': 3},
#   {'id': 506, 'name': 'pitta cyanea', 'count': 4},
#   {'id': 507, 'name': 'macaca mulatta', 'count': 3},
#   {'id': 508, 'name': 'lophura diardi', 'count': 42},
#   {'id': 509, 'name': 'mustela strigidorsa', 'count': 2},
#   {'id': 510, 'name': 'sus sp', 'count': 198},
#   {'id': 511, 'name': 'unknown deer', 'count': 1},
#   {'id': 512, 'name': 'unknown turtle', 'count': 3},
#   {'id': 513, 'name': 'nisaetus nipalensis', 'count': 3},
#   {'id': 514, 'name': 'hydrornis cyaneus', 'count': 2},
#   {'id': 515, 'name': 'cissa chinensis', 'count': 1},
#   {'id': 516, 'name': 'melogale personata', 'count': 1},
#   {'id': 517, 'name': 'nisaetus nanus', 'count': 2},
#   {'id': 518, 'name': 'callosciurus erythraeus', 'count': 5},
#   {'id': 519, 'name': 'trochalopteron milnei', 'count': 3},
#   {'id': 520, 'name': 'luscinia cyane', 'count': 1},
#   {'id': 521, 'name': 'iduna aedon', 'count': 1},
#   {'id': 522, 'name': 'ficedula tricolor', 'count': 1},
#   {'id': 523, 'name': 'butastur indicus', 'count': 2},
#   {'id': 524, 'name': 'aquila heliaca', 'count': 2},
#   {'id': 525, 'name': 'ratufa bicolor', 'count': 4},
#   {'id': 526, 'name': 'cyornis banyumas', 'count': 3},
#   {'id': 527, 'name': 'pomatorhinus mcclellandi', 'count': 1},
#   {'id': 528, 'name': 'pernis ptilorhynchus', 'count': 2},
#   {'id': 529, 'name': 'unidentified', 'count': 39},
#   {'id': 530, 'name': 'varanus sp', 'count': 3},
#   {'id': 531, 'name': 'copsychus malabaricus', 'count': 3},
#   {'id': 532, 'name': 'copsychus saularis', 'count': 1},
#   {'id': 533, 'name': 'geokichla citrina', 'count': 3},
#   {'id': 534, 'name': 'unknown cat', 'count': 1},
#   {'id': 535, 'name': 'mustela kathiah', 'count': 1},
#   {'id': 536, 'name': 'enicurus schistaceus', 'count': 3},
#   {'id': 537, 'name': 'turdus sp', 'count': 1499},
#   {'id': 538, 'name': 'lagidium viscacia', 'count': 336},
#   {'id': 539, 'name': 'grallaria andicolus', 'count': 116},
#   {'id': 540, 'name': 'mustela frenata', 'count': 61},
#   {'id': 541, 'name': 'hippocamelus antisensis', 'count': 115},
#   {'id': 542, 'name': 'lycalopex culpaeus', 'count': 1391},
#   {'id': 543, 'name': 'conepatus chinga', 'count': 413},
#   {'id': 544, 'name': 'equus caballus', 'count': 252},
#   {'id': 545, 'name': 'vicugna pacos', 'count': 1232},
#   {'id': 546, 'name': 'cinclodes fuscus', 'count': 53},
#   {'id': 547, 'name': 'zonatrichia capensis', 'count': 3},
#   {'id': 548, 'name': 'cinclodes atacamensis', 'count': 21},
#   {'id': 549, 'name': 'cinclodes sp', 'count': 21},
#   {'id': 550, 'name': 'odontophorus balliviani', 'count': 30},
#   {'id': 551, 'name': 'muntiacus sp', 'count': 6},
#   {'id': 552, 'name': 'carpococcyx renauldi', 'count': 1},
#   {'id': 553, 'name': 'tupaia belangeri', 'count': 1},
#   {'id': 554, 'name': 'rhizomys sp', 'count': 1},
#   {'id': 555, 'name': 'melogale everetti', 'count': 22},
#   {'id': 556, 'name': 'zoothera sp', 'count': 2},
#   {'id': 557, 'name': 'muntiacus vuquangensis', 'count': 10},
#   {'id': 558, 'name': 'motorcycle', 'count': 3423},
#   {'id': 559, 'name': 'peromyscus sp', 'count': 304},
#   {'id': 560, 'name': 'buteogallus urobitinga', 'count': 1},
#   {'id': 561, 'name': 'unknown raptor', 'count': 279},
#   {'id': 562, 'name': 'puma yagoroundi', 'count': 110},
#   {'id': 563, 'name': 'tigrisoma mexicanum', 'count': 20},
#   {'id': 564, 'name': 'canis latrans', 'count': 40},
#   {'id': 565, 'name': 'claravis pretiosa', 'count': 160},
#   {'id': 566, 'name': 'sciurus sp', 'count': 411},
#   {'id': 567, 'name': 'ave desconocida', 'count': 250},
#   {'id': 568, 'name': 'aramides cajanea', 'count': 275},
#   {'id': 569, 'name': 'unknown dove', 'count': 10},
#   {'id': 570, 'name': 'aramus guarauna', 'count': 40},
#   {'id': 571, 'name': 'mazama  temama', 'count': 10},
#   {'id': 572, 'name': 'fossa fossana', 'count': 1101},
#   {'id': 573, 'name': 'nesomys sp', 'count': 1499},
#   {'id': 574, 'name': 'setifer sp', 'count': 247},
#   {'id': 575, 'name': 'galidictis fasciata', 'count': 127},
#   {'id': 576, 'name': 'eupleres goudotii', 'count': 246},
#   {'id': 577, 'name': 'canirallus kioloides', 'count': 600},
#   {'id': 578, 'name': 'rattus rattus', 'count': 132},
#   {'id': 579, 'name': 'tenrec ecaudatus', 'count': 97},
#   {'id': 580, 'name': 'copsychus albospecularis', 'count': 711},
#   {'id': 581, 'name': 'galidia elegans', 'count': 354},
#   {'id': 582, 'name': 'mystacornis crossleyi', 'count': 4},
#   {'id': 583, 'name': 'lophotibis cristataa', 'count': 1176},
#   {'id': 584, 'name': 'cryptoprocta ferox', 'count': 729},
#   {'id': 585, 'name': 'coua serriana', 'count': 4501},
#   {'id': 586, 'name': 'propithecus candidus', 'count': 6},
#   {'id': 587, 'name': 'eliurus sp', 'count': 287},
#   {'id': 588, 'name': 'reptile', 'count': 14},
#   {'id': 589, 'name': 'coua ruficeps', 'count': 78},
#   {'id': 590, 'name': 'streptopelia picturata', 'count': 327},
#   {'id': 591, 'name': 'brachypteracias squamiger', 'count': 1414},
#   {'id': 592, 'name': 'coua sp', 'count': 25},
#   {'id': 593, 'name': 'salanoia concolor', 'count': 82},
#   {'id': 594, 'name': 'asio madagascariensis', 'count': 3},
#   {'id': 595, 'name': 'suncus murinus', 'count': 50},
#   {'id': 596, 'name': 'atelornis pittoides', 'count': 8},
#   {'id': 597, 'name': 'tenrec', 'count': 9},
#   {'id': 598, 'name': 'lemur', 'count': 44},
#   {'id': 599, 'name': 'unknown mouse or rat', 'count': 813},
#   {'id': 600, 'name': 'hemicentetes semispinosus', 'count': 23},
#   {'id': 601, 'name': 'eutriorchis astur', 'count': 6},
#   {'id': 602, 'name': 'haliaeetus vociferoides', 'count': 2},
#   {'id': 603, 'name': 'oxylabes madagascariensis', 'count': 14},
#   {'id': 604, 'name': 'daubentonia madagascariensis', 'count': 5},
#   {'id': 605, 'name': 'coturnix delegorguei', 'count': 3},
#   {'id': 606, 'name': 'eliurus petteri', 'count': 98},
#   {'id': 607, 'name': 'skink', 'count': 22},
#   {'id': 608, 'name': 'flying insect', 'count': 4},
#   {'id': 609, 'name': 'unknown shrew', 'count': 28},
#   {'id': 610, 'name': 'lophotibis cristata', 'count': 234},
#   {'id': 611, 'name': 'felis sp', 'count': 462},
#   {'id': 612, 'name': 'phyllastrephus apperti', 'count': 3},
#   {'id': 613, 'name': 'terpsiphone mutata', 'count': 3},
#   {'id': 614, 'name': 'microgale sp', 'count': 7},
#   {'id': 615, 'name': 'coua', 'count': 7},
#   {'id': 616, 'name': 'hypogeomys antimena', 'count': 554},
#   {'id': 617, 'name': 'geobiastes squamiger', 'count': 322},
#   {'id': 618, 'name': 'eliurus penicillatus', 'count': 161},
#   {'id': 619, 'name': 'nesoenas picturata', 'count': 465},
#   {'id': 620, 'name': 'snake', 'count': 4},
#   {'id': 621, 'name': 'coua caerulea', 'count': 45},
#   {'id': 622, 'name': 'nesomys audeberti', 'count': 3},
#   {'id': 623, 'name': 'eliurus webbi', 'count': 1},
#   {'id': 624, 'name': 'cospsychus albospecularis', 'count': 29},
#   {'id': 625, 'name': 'saxicola tectes', 'count': 9},
#   {'id': 626, 'name': 'accipiter madagascariensis', 'count': 9},
#   {'id': 627, 'name': 'cisticola cherina', 'count': 122},
#   {'id': 628, 'name': 'eliurus spp', 'count': 163},
#   {'id': 629, 'name': 'eulemur albifrons', 'count': 3},
#   {'id': 630, 'name': 'euryceros prevostii', 'count': 15},
#   {'id': 631, 'name': 'small mammal', 'count': 241},
#   {'id': 632, 'name': 'millipede', 'count': 6},
#   {'id': 633, 'name': 'motacilla flaviventris', 'count': 3},
#   {'id': 634, 'name': 'tufted tailed rat', 'count': 3},
#   {'id': 635, 'name': 'microcebus murinus', 'count': 5},
#   {'id': 636, 'name': 'crypturellus boucardi', 'count': 13},
#   {'id': 637, 'name': 'arremonops chloronotus', 'count': 1},
#   {'id': 638, 'name': 'crypturellus cinnamomeus', 'count': 1},
#   {'id': 639, 'name': 'philander oppossum', 'count': 1},
#   {'id': 640, 'name': 'spilogale putorius', 'count': 2},
#   {'id': 641, 'name': 'meleagris ocellote', 'count': 1},
#   {'id': 642, 'name': 'nightjar', 'count': 1},
#   {'id': 643, 'name': 'nyctanassa violacea', 'count': 1},
#   {'id': 644, 'name': 'catharus sp', 'count': 5},
#   {'id': 645, 'name': 'crypturelus sp', 'count': 2},
#   {'id': 646, 'name': 'catharus mustelinus', 'count': 9},
#   {'id': 647, 'name': 'dasyprocta leporina', 'count': 5245},
#   {'id': 648, 'name': 'crax alector', 'count': 1427},
#   {'id': 649, 'name': 'didelphis imperfecta', 'count': 102},
#   {'id': 650, 'name': 'unknown opossum', 'count': 309},
#   {'id': 651, 'name': 'mesembrinis cayannensis', 'count': 71},
#   {'id': 652, 'name': 'myoprocta pratii', 'count': 535},
#   {'id': 653, 'name': 'metachirus nudicudatus', 'count': 21},
#   {'id': 654, 'name': 'unknown armadillo', 'count': 923},
#   {'id': 655, 'name': 'mazama gouazaoubira', 'count': 302},
#   {'id': 656, 'name': 'unknown cervid', 'count': 6},
#   {'id': 657, 'name': 'catharus ustulatus', 'count': 10},
#   {'id': 658, 'name': 'leopardus weidii', 'count': 10},
#   {'id': 659, 'name': 'tayassu tajacu', 'count': 431},
#   {'id': 660, 'name': 'mitu tomentosa', 'count': 186},
#   {'id': 661, 'name': 'cabassous unicintus', 'count': 5},
#   {'id': 662, 'name': 'puma yaguaroundi', 'count': 17},
#   {'id': 663, 'name': 'crypturellus variegatus', 'count': 62},
#   {'id': 664, 'name': 'unknown pig_peccary', 'count': 32},
#   {'id': 665, 'name': 'neomorphus rufipennis', 'count': 5},
#   {'id': 666, 'name': 'pipile pipile', 'count': 2},
#   {'id': 667, 'name': 'metachirus nudicaudatus', 'count': 2},
#   {'id': 668, 'name': 'funisciurus pyrropus', 'count': 119},
#   {'id': 669, 'name': 'alethe poliophrys', 'count': 6},
#   {'id': 670, 'name': 'ruwenzorornis johnstoni', 'count': 6},
#   {'id': 671, 'name': 'thryonomys swinderianus', 'count': 6},
#   {'id': 672, 'name': 'ploceus alienus', 'count': 3},
#   {'id': 673, 'name': 'ploceus baglafecht', 'count': 3},
#   {'id': 674, 'name': 'poecilogale albinucha', 'count': 2},
#   {'id': 675, 'name': 'anomalurus derbianus', 'count': 6}]}
